# %% [markdown]
# ###### Task-1: -
# *   Take one image and create its histogram equalization.
# *   Now stack the equalized and original image side by side.

# %% [markdown]
# ###### Task-2: -
# *   Write a python code which can open your default webcam using open cv and identify that if there is any QR code present in the frame in real time.  The program should open browser if there is any hyperlink present in that QR code.

# %% [markdown]
# ##### Image  histogram equalization: -

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %%
img = cv2.imread(r"C:/Users/Ganpati Kumar Roy/File/Pictures/Personal Data/Photo/Ganpati Roy.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img = cv2.imread(r"C:/Users/Ganpati Kumar Roy/File/Pictures/Personal Data/Photo/Ganpati Roy.png")
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# ##### Stacking images side-by-side: -

# %%
my_img = cv2.imread(r"C:/Users/Ganpati Kumar Roy/File/Pictures/Personal Data/Photo/Ganpati Roy.png")
equ = cv2.equalizeHist(my_img)
res = np.hstack((my_img, equ))
cv2.imshow('image', res)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-20-aaee12c27bfc> in <module>
#       1 my_img = cv2.imread(r"C:/Users/Ganpati Kumar Roy/File/Pictures/Personal Data/Photo/Ganpati Roy.png")
# ----> 2 equ = cv2.equalizeHist(my_img)
#       3 res = np.hstack((my_img, equ))
#       4 cv2.imshow('image', res)
#       5 cv2.waitKey(0)
#
# error: OpenCV(4.5.4) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\histogram.cpp:3439: error: (-215:Assertion failed) _src.type() == CV_8UC1 in function 'cv::equalizeHist'
